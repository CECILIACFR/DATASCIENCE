# %% [markdown]
# <a href="https://colab.research.google.com/github/CECILIACFR/DATASCIENCE/blob/main/MVP_CD_SkiingHotels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MVP de Análise e Boas Práticas
#
# ## Profs. Tatiana Escovedo e Hugo Villamizar
#
# ### Aluna: Cecilia Correa Ferrari Rey
#
# ### MVP Hotéis de Esqui na Europa

# %% [markdown]
# ##1.Definição do Problema

# %% [markdown]
# O dataset usado neste projeto será o **Skiing Hotels**, proveniente da plataforma Kaggle, sobre Hotéis em resorts de Esqui em toda a Europa, contendo detalhes sobre os resorts onde estão localizados, como preço (em libras esterlinas) por pessoa por semana, número de elevadores no resort, distância total da pista e neve registrada em 2020 em cada resort.  Para mais detalhes sobre este dataset, consulte: https://www.kaggle.com/datasets/jacklacey/skiing-hotels.
#
# Este Notebook de Análise Eploratória de um arquivo CSV, serve para checar a exsitência de valores faltantes, entender a distribuição de dados, verificar as relações entre os dados.  Através de visualizações tiraremos conclusões sobre quais são os dados mais relevantes e quais talvez precisemos manter fora de nossos modelos. Também investigamos um modelo de linha de base muito simples.
#
# **Informações sobre os atributos:**
#
# 1. **index**: Uma coluna de índice.
# 2. **country**: O país onde o hotel está localizado.
# 3. **resort**: O resort onde o hotel está loca.lizado.
# 4. **hotel**: O nome do hotel.
# 5. **price**: O preço (em libras esterlinas) por pessoa por semana.
# 6. **distance_lift**: A distância do hotel ao teleférico mais próximo, em metros.
# 7. **altitude**:  A altitude do hotel, em metros.
# 8. **totalLifts**: O total de elevadores (teleféricos) no resort.
# 9.  **gondolas**: O total de gôndolas no resort.
# 10. **chairlifts**: O total de cadeiras no resort.
# 11. **draglifts**: O total de draglift no resort.
# 12. **blues**: O total de pistas azuis - dificuldade baixa.
# 13. **reds**: O total de pistas vermelhas - dificuldade média.
# 14. **blacks**: O total de pistas pretas - dificuldade alta.
# 15. **totalRuns**: A distância total da pista em Km.
# 16. **link**: O link do Hotél de Esqui.
# 17. **sleeps**: O número de pessoas que podem dormir no Hotel de Esqui.
# 18. **decSnowLow2020**: A quantidade de neve nas encontas mais baixas em dezembro de 2020 em cm.
# 19. **decSnowHigh2020**: A quantidade de neve nas encontas mais altas em dezembro de 2020 em cm.
# 20. **janSnowLow2020**: A quantidade de neve nas encontas mais baixas em janeiro de 2020 em cm.
# 21. **janSnowHigh2020**: A quantidade de neve nas encontas mais altas em janeiro de 2020 em cm.
# 22. **febSnowLow2020**: A quantidade de neve nas encontas mais baixas em fevereiro de 2020 em cm.
# 23. **febSnowHigh2020**: A quantidade de neve nas encontas mais altas em fevereiro de 2020 em cm.

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
import gc
import seaborn as sns
import missingno as ms # para tratamento de missings
from matplotlib import cm
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##2.Carga de Dados
#
# Será carregado arquivo CSV usando Pandas usando uma URL de meu repositório do GitHUb sem cabeçalho disponível online.
#
# Com o dataset caregado, irei explrá-lo um pouco.

# %%
# Carrega arquivo csv usando uma URL

# Informa a URL de importação do dataset
url = "https://raw.githubusercontent.com/CECILIACFR/DATASCIENCE/main/ski_hotels.csv"

# Informa o cabeçalho das colunas
colunas = ['index','country', 'resort', 'hotel', 'price', 'distance_lift', 'altitude', 'totalPiste', 'totalLifts', 'gondolas', 'chairlifts', 'draglifts', 'blues', 'reds', 'blacks', 'totalRuns', 'link', 'sleeps', 'decSnowLow2020', 'decSnowHigh2020', 'janSnowLow2020', 'janSnowHigh2020', 'febSnowLow2020', 'febSnowHigh2020']

# Lê o arquivo utilizando as colunas informadas]
dataset = pd.read_csv(url, names=colunas, skiprows=1, delimiter=',')

# Verificando que dataset é um dataframe
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# Verficando as primeiras linhas do dataset
dataset.head()
# Out:
#    index   country        resort                   hotel  price distance_lift  \
# 0      0     italy  bardonecchia         residence-tabor    550       unknown
# 1      1     italy  bardonecchia  residence-villa-frejus    561       unknown
# 2      2  bulgaria        bansko              hotel-mura    566          1100
# 3      3  bulgaria      borovets           hotel-samokov    574            75
# 4      4  bulgaria        bansko     hotel-lion---bansko    596           800
#
#    altitude  totalPiste  totalLifts  gondolas  ...  blacks  totalRuns  \
# 0      1312         140          23         0  ...     1.0       42.0
# 1      1312         140          23         0  ...     1.0       42.0
# 2       935          70          24         1  ...     1.0       14.0
# 3      1390          58          18         1  ...     1.0       15.0
# 4       935          70          24         1  ...     1.0       14.0
#
#                                                 link   sleeps  decSnowLow2020  \
# 0  https://www.igluski.com/ski-resorts/italy/bard...  unknown              70
# 1  https://www.igluski.com/ski-resorts/italy/bard...  unknown              70
# 2  https://www.igluski.com/ski-resorts/bulgaria/b...      140               0
# 3  https://www.igluski.com/ski-resorts/bulgaria/b...      590               0
# 4  https://www.igluski.com/ski-resorts/bulgaria/b...      386               0
#
#    decSnowHigh2020 janSnowLow2020 janSnowHigh2020 febSnowLow2020  \
# 0              170             60             200             47
# 1              170             60             200             47
# 2               70              5              75              5
# 3                0            160             200            194
# 4               70              5              75              5
#
#   febSnowHigh2020
# 0             177
# 1             177
# 2              77
# 3             246
# 4              77
#
# [5 rows x 24 columns]

# %% [markdown]
# Ao analisar as primeiras linhas do dataset, é possível perceber que existem valores faltantes ("**unknown**"), como nas colunas "**distance_lift**" e "**sleeps**", e ainda verifica-se que os dados da primeira coluna denominada **index**, tem conteúdo que não será necessário.

# %%
# Exclue a primeira coluna do dataset
dataset = dataset.drop(columns=['index'])

# %%
# Verficando novamente as primeiras linhas do dataset
dataset.head()
# Out:
#     country        resort                   hotel  price distance_lift  \
# 0     italy  bardonecchia         residence-tabor    550       unknown
# 1     italy  bardonecchia  residence-villa-frejus    561       unknown
# 2  bulgaria        bansko              hotel-mura    566          1100
# 3  bulgaria      borovets           hotel-samokov    574            75
# 4  bulgaria        bansko     hotel-lion---bansko    596           800
#
#    altitude  totalPiste  totalLifts  gondolas  chairlifts  ...  blacks  \
# 0      1312         140          23         0           9  ...     1.0
# 1      1312         140          23         0           9  ...     1.0
# 2       935          70          24         1           7  ...     1.0
# 3      1390          58          18         1           4  ...     1.0
# 4       935          70          24         1           7  ...     1.0
#
#    totalRuns                                               link   sleeps  \
# 0       42.0  https://www.igluski.com/ski-resorts/italy/bard...  unknown
# 1       42.0  https://www.igluski.com/ski-resorts/italy/bard...  unknown
# 2       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...      140
# 3       15.0  https://www.igluski.com/ski-resorts/bulgaria/b...      590
# 4       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...      386
#
#    decSnowLow2020 decSnowHigh2020 janSnowLow2020 janSnowHigh2020  \
# 0              70             170             60             200
# 1              70             170             60             200
# 2               0              70              5              75
# 3               0               0            160             200
# 4               0              70              5              75
#
#   febSnowLow2020 febSnowHigh2020
# 0             47             177
# 1             47             177
# 2              5              77
# 3            194             246
# 4              5              77
#
# [5 rows x 23 columns]

# %% [markdown]
# ##3.Análise de Dados

# %% [markdown]
# ###3.1.Estatístcias Descritivas
#
# Vamos iniciar examinando as dimensões do dataset, suas informações e alguns exemplos de linhas.

# %%
# Mostra as dimensões do dataset
print(dataset.shape)
# Out:
# (407, 23)

# %% [markdown]
# O dataset possui e 407 instâncias (linhas) e 23 atributos (colunas).

# %%
# Mostra as informações do dataset
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          407 non-null    object
#  1   resort           407 non-null    object
#  2   hotel            407 non-null    object
#  3   price            407 non-null    int64
#  4   distance_lift    407 non-null    object
#  5   altitude         407 non-null    int64
#  6   totalPiste       407 non-null    int64
#  7   totalLifts       407 non-null    int64
#  8   gondolas         407 non-null    int64
#  9   chairlifts       407 non-null    int64
#  10  draglifts        407 non-null    int64
#  11  blues            407 non-null    float64
#  12  reds             407 non-null    float64
#  13  blacks           407 non-null    float64
#  14  totalRuns        407 non-null    float64
#  15  link             407 non-null    object
#  16  sleeps           407 non-null    object
#  17  decSnowLow2020   407 non-null    object
#  18  decSnowHigh2020  407 non-null    object
#  19  janSnowLow2020   407 non-null    object
#  20  janSnowHigh2020  407 non-null    object
#  21  febSnowLow2020   407 non-null    object
#  22  febSnowHigh2020  407 non-null    object
# dtypes: float64(4), int64(7), object(12)
# memory usage: 73.3+ KB
# None

# %%
# Exibindo os nomes das colunas
dataset.columns
# Out:
# Index(['country', 'resort', 'hotel', 'price', 'distance_lift', 'altitude',
#        'totalPiste', 'totalLifts', 'gondolas', 'chairlifts', 'draglifts',
#        'blues', 'reds', 'blacks', 'totalRuns', 'link', 'sleeps',
#        'decSnowLow2020', 'decSnowHigh2020', 'janSnowLow2020',
#        'janSnowHigh2020', 'febSnowLow2020', 'febSnowHigh2020'],
#       dtype='object')

# %%
# Exibindo a quantidade de linhas por coluna
dataset.count()
# Out:
# country            407
# resort             407
# hotel              407
# price              407
# distance_lift      407
# altitude           407
# totalPiste         407
# totalLifts         407
# gondolas           407
# chairlifts         407
# draglifts          407
# blues              407
# reds               407
# blacks             407
# totalRuns          407
# link               407
# sleeps             407
# decSnowLow2020     407
# decSnowHigh2020    407
# janSnowLow2020     407
# janSnowHigh2020    407
# febSnowLow2020     407
# febSnowHigh2020    407
# dtype: int64

# %%
# Verifica o tipo de dataset de cada atributo
dataset.dtypes
# Out:
# country             object
# resort              object
# hotel               object
# price                int64
# distance_lift       object
# altitude             int64
# totalPiste           int64
# totalLifts           int64
# gondolas             int64
# chairlifts           int64
# draglifts            int64
# blues              float64
# reds               float64
# blacks             float64
# totalRuns          float64
# link                object
# sleeps              object
# decSnowLow2020      object
# decSnowHigh2020     object
# janSnowLow2020      object
# janSnowHigh2020     object
# febSnowLow2020      object
# febSnowHigh2020     object
# dtype: object

# %%
# Mostra as 10 primeiras linhas do dataset
dataset.head(10)
# Out:
#     country        resort                   hotel  price distance_lift  \
# 0     italy  bardonecchia         residence-tabor    550       unknown
# 1     italy  bardonecchia  residence-villa-frejus    561       unknown
# 2  bulgaria        bansko              hotel-mura    566          1100
# 3  bulgaria      borovets           hotel-samokov    574            75
# 4  bulgaria        bansko     hotel-lion---bansko    596           800
# 5   andorra       arinsal      hotel-xalet-besoli    597           500
# 6   austria     mayrhofen          hotel-obermair    601           600
# 7  bulgaria      borovets     hotel-lion-borovets    603          1200
# 8   andorra       arinsal       hotel-xalet-verdu    606           300
# 9   andorra       arinsal         hotel-patagonia    632           100
#
#    altitude  totalPiste  totalLifts  gondolas  chairlifts  ...  blacks  \
# 0      1312         140          23         0           9  ...     1.0
# 1      1312         140          23         0           9  ...     1.0
# 2       935          70          24         1           7  ...     1.0
# 3      1390          58          18         1           4  ...     1.0
# 4       935          70          24         1           7  ...     1.0
# 5      1550          63          30         2          11  ...     4.0
# 6       630         600          52         8          27  ...    15.0
# 7      1390          58          18         1           4  ...     1.0
# 8      1550          63          30         2          11  ...     4.0
# 9      1550          63          30         2          11  ...     4.0
#
#    totalRuns                                               link   sleeps  \
# 0       42.0  https://www.igluski.com/ski-resorts/italy/bard...  unknown
# 1       42.0  https://www.igluski.com/ski-resorts/italy/bard...  unknown
# 2       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...      140
# 3       15.0  https://www.igluski.com/ski-resorts/bulgaria/b...      590
# 4       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...      386
# 5       42.0  https://www.igluski.com/ski-resorts/andorra/ar...       66
# 6      133.0  https://www.igluski.com/ski-resorts/austria/ma...       60
# 7       15.0  https://www.igluski.com/ski-resorts/bulgaria/b...      314
# 8       42.0  https://www.igluski.com/ski-resorts/andorra/ar...      104
# 9       42.0  https://www.igluski.com/ski-resorts/andorra/ar...      160
#
#    decSnowLow2020 decSnowHigh2020 janSnowLow2020 janSnowHigh2020  \
# 0              70             170             60             200
# 1              70             170             60             200
# 2               0              70              5              75
# 3               0               0            160             200
# 4               0              70              5              75
# 5              30              60            130             180
# 6               0              60              5              80
# 7               0               0            160             200
# 8              30              60            130             180
# 9              30              60            130             180
#
#   febSnowLow2020 febSnowHigh2020
# 0             47             177
# 1             47             177
# 2              5              77
# 3            194             246
# 4              5              77
# 5            120             170
# 6              2              99
# 7            194             246
# 8            120             170
# 9            120             170
#
# [10 rows x 23 columns]

# %%
dataset.head().style.background_gradient(cmap = "Purples")
# Out:
# <style type="text/css">
# #T_25a3e_row0_col3, #T_25a3e_row0_col8, #T_25a3e_row0_col13, #T_25a3e_row1_col8, #T_25a3e_row1_col13, #T_25a3e_row2_col5, #T_25a3e_row2_col12, #T_25a3e_row2_col13, #T_25a3e_row2_col14, #T_25a3e_row3_col6, #T_25a3e_row3_col7, #T_25a3e_row3_col9, #T_25a3e_row3_col10, #T_25a3e_row3_col11, #T_25a3e_row3_col13, #T_25a3e_row4_col5, #T_25a3e_row4_col12, #T_25a3e_row4_col13, #T_25a3e_row4_col14 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_25a3e_row0_col5, #T_25a3e_row1_col5 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_25a3e_row0_col6, #T_25a3e_row0_col9, #T_25a3e_row0_col11, #T_25a3e_row0_col12, #T_25a3e_row0_col14, #T_25a3e_row1_col6, #T_25a3e_row1_col9, #T_25a3e_row1_col11, #T_25a3e_row1_col12, #T_25a3e_row1_col14, #T_25a3e_row2_col7, #T_25a3e_row2_col8, #T_25a3e_row2_col10, #T_25a3e_row3_col5, #T_25a3e_row3_col8, #T_25a3e_row4_col3, #T_25a3e_row4_col7, #T_25a3e_row4_col8, #T_25a3e_row4_col10 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_25a3e_row0_col7, #T_25a3e_row1_col7 {
#   background-color: #5b3495;
#   color: #f1f1f1;
# }
# #T_25a3e_row0_col10, #T_25a3e_row1_col10 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_25a3e_row1_col3 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_25a3e_row2_col3 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_25a3e_row2_col6, #T_25a3e_row4_col6 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_25a3e_row2_col9, #T_25a3e_row4_col9 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_25a3e_row2_col11, #T_25a3e_row4_col11 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_25a3e_row3_col3 {
#   background-color: #9995c6;
#   color: #f1f1f1;
# }
# #T_25a3e_row3_col12 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_25a3e_row3_col14 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# </style>
# <table id="T_25a3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25a3e_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_25a3e_level0_col1" class="col_heading level0 col1" >resort</th>
#       <th id="T_25a3e_level0_col2" class="col_heading level0 col2" >hotel</th>
#       <th id="T_25a3e_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_25a3e_level0_col4" class="col_heading level0 col4" >distance_lift</th>
#       <th id="T_25a3e_level0_col5" class="col_heading level0 col5" >altitude</th>
#       <th id="T_25a3e_level0_col6" class="col_heading level0 col6" >totalPiste</th>
#       <th id="T_25a3e_level0_col7" class="col_heading level0 col7" >totalLifts</th>
#       <th id="T_25a3e_level0_col8" class="col_heading level0 col8" >gondolas</th>
#       <th id="T_25a3e_level0_col9" class="col_heading level0 col9" >chairlifts</th>
#       <th id="T_25a3e_level0_col10" class="col_heading level0 col10" >draglifts</th>
#       <th id="T_25a3e_level0_col11" class="col_heading level0 col11" >blues</th>
#       <th id="T_25a3e_level0_col12" class="col_heading level0 col12" >reds</th>
#       <th id="T_25a3e_level0_col13" class="col_heading level0 col13" >blacks</th>
#       <th id="T_25a3e_level0_col14" class="col_heading level0 col14" >totalRuns</th>
#       <th id="T_25a3e_level0_col15" class="col_heading level0 col15" >link</th>
#       <th id="T_25a3e_level0_col16" class="col_heading level0 col16" >sleeps</th>
#       <th id="T_25a3e_level0_col17" class="col_heading level0 col17" >decSnowLow2020</th>
#       <th id="T_25a3e_level0_col18" class="col_heading level0 col18" >decSnowHigh2020</th>
#       <th id="T_25a3e_level0_col19" class="col_heading level0 col19" >janSnowLow2020</th>
#       <th id="T_25a3e_level0_col20" class="col_heading level0 col20" >janSnowHigh2020</th>
#       <th id="T_25a3e_level0_col21" class="col_heading level0 col21" >febSnowLow2020</th>
#       <th id="T_25a3e_level0_col22" class="col_heading level0 col22" >febSnowHigh2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25a3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25a3e_row0_col0" class="data row0 col0" >italy</td>
#       <td id="T_25a3e_row0_col1" class="data row0 col1" >bardonecchia</td>
#       <td id="T_25a3e_row0_col2" class="data row0 col2" >residence-tabor</td>
#       <td id="T_25a3e_row0_col3" class="data row0 col3" >550</td>
#       <td id="T_25a3e_row0_col4" class="data row0 col4" >unknown</td>
#       <td id="T_25a3e_row0_col5" class="data row0 col5" >1312</td>
#       <td id="T_25a3e_row0_col6" class="data row0 col6" >140</td>
#       <td id="T_25a3e_row0_col7" class="data row0 col7" >23</td>
#       <td id="T_25a3e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_25a3e_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_25a3e_row0_col10" class="data row0 col10" >14</td>
#       <td id="T_25a3e_row0_col11" class="data row0 col11" >17.000000</td>
#       <td id="T_25a3e_row0_col12" class="data row0 col12" >24.000000</td>
#       <td id="T_25a3e_row0_col13" class="data row0 col13" >1.000000</td>
#       <td id="T_25a3e_row0_col14" class="data row0 col14" >42.000000</td>
#       <td id="T_25a3e_row0_col15" class="data row0 col15" >https://www.igluski.com/ski-resorts/italy/bardonecchia/residence-tabor_38648?holidayId=58413613</td>
#       <td id="T_25a3e_row0_col16" class="data row0 col16" >unknown</td>
#       <td id="T_25a3e_row0_col17" class="data row0 col17" >70</td>
#       <td id="T_25a3e_row0_col18" class="data row0 col18" >170</td>
#       <td id="T_25a3e_row0_col19" class="data row0 col19" >60</td>
#       <td id="T_25a3e_row0_col20" class="data row0 col20" >200</td>
#       <td id="T_25a3e_row0_col21" class="data row0 col21" >47</td>
#       <td id="T_25a3e_row0_col22" class="data row0 col22" >177</td>
#     </tr>
#     <tr>
#       <th id="T_25a3e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25a3e_row1_col0" class="data row1 col0" >italy</td>
#       <td id="T_25a3e_row1_col1" class="data row1 col1" >bardonecchia</td>
#       <td id="T_25a3e_row1_col2" class="data row1 col2" >residence-villa-frejus</td>
#       <td id="T_25a3e_row1_col3" class="data row1 col3" >561</td>
#       <td id="T_25a3e_row1_col4" class="data row1 col4" >unknown</td>
#       <td id="T_25a3e_row1_col5" class="data row1 col5" >1312</td>
#       <td id="T_25a3e_row1_col6" class="data row1 col6" >140</td>
#       <td id="T_25a3e_row1_col7" class="data row1 col7" >23</td>
#       <td id="T_25a3e_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_25a3e_row1_col9" class="data row1 col9" >9</td>
#       <td id="T_25a3e_row1_col10" class="data row1 col10" >14</td>
#       <td id="T_25a3e_row1_col11" class="data row1 col11" >17.000000</td>
#       <td id="T_25a3e_row1_col12" class="data row1 col12" >24.000000</td>
#       <td id="T_25a3e_row1_col13" class="data row1 col13" >1.000000</td>
#       <td id="T_25a3e_row1_col14" class="data row1 col14" >42.000000</td>
#       <td id="T_25a3e_row1_col15" class="data row1 col15" >https://www.igluski.com/ski-resorts/italy/bardonecchia/residence-villa-frejus_38647?holidayId=58464837</td>
#       <td id="T_25a3e_row1_col16" class="data row1 col16" >unknown</td>
#       <td id="T_25a3e_row1_col17" class="data row1 col17" >70</td>
#       <td id="T_25a3e_row1_col18" class="data row1 col18" >170</td>
#       <td id="T_25a3e_row1_col19" class="data row1 col19" >60</td>
#       <td id="T_25a3e_row1_col20" class="data row1 col20" >200</td>
#       <td id="T_25a3e_row1_col21" class="data row1 col21" >47</td>
#       <td id="T_25a3e_row1_col22" class="data row1 col22" >177</td>
#     </tr>
#     <tr>
#       <th id="T_25a3e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25a3e_row2_col0" class="data row2 col0" >bulgaria</td>
#       <td id="T_25a3e_row2_col1" class="data row2 col1" >bansko</td>
#       <td id="T_25a3e_row2_col2" class="data row2 col2" >hotel-mura</td>
#       <td id="T_25a3e_row2_col3" class="data row2 col3" >566</td>
#       <td id="T_25a3e_row2_col4" class="data row2 col4" >1100</td>
#       <td id="T_25a3e_row2_col5" class="data row2 col5" >935</td>
#       <td id="T_25a3e_row2_col6" class="data row2 col6" >

# %% [markdown]
# As primeiras linhas do dataset exibidas acima demonstram as seguintes **informações quantitativas** mais relevantes, a saber:
#
# *   o **preço** (coluna "**price**") dos hotéis são de valores bem próximos, em torno de 500 libras esterlinas;
# *   na coluna **"altitude"** veriica-se que a altitude de 3 hotéis é em torno de 1.300m;
# *   o **total de teleféricos** (coluna "**totalLifts**") é quase a mesma nos 5 hotéis exibidos;
# *   o **total do gôndolas** (coluna "**gondolas**") é pequeno para cada hotel, sendo que nesta análise 2 hotéis não possuem gôndolas e 3 possuem uma única gôndola;
# *   o **total de pistas blacks** (coluna "**blacks**") é 1 para cada um dos 5 hotéis exibidos.

# %%
dataset.describe()
# Out:
#              price     altitude   totalPiste  totalLifts    gondolas  \
# count   407.000000   407.000000   407.000000  407.000000  407.000000
# mean   1095.027027  1358.781327   220.270270   60.395577    9.108108
# std     342.841268   508.322847   164.592139   39.025295    8.398517
# min     550.000000   180.000000     0.000000    0.000000    0.000000
# 25%     839.000000   900.000000   110.000000   30.000000    3.000000
# 50%    1021.000000  1441.000000   185.000000   55.000000    8.000000
# 75%    1270.500000  1800.000000   282.000000   82.000000   11.000000
# max    2517.000000  2300.000000  1220.000000  206.000000   43.000000
#
#        chairlifts   draglifts       blues        reds      blacks   totalRuns
# count  407.000000  407.000000  407.000000  407.000000  407.000000  407.000000
# mean    24.766585   25.189189   41.115479   45.685504   14.007371  100.808354
# std     16.968010   19.300095   40.742178   38.777112   12.131969   81.835216
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     12.000000   12.000000   16.000000   18.000000    4.000000   40.000000
# 50%     22.000000   21.000000   30.000000   37.000000    9.000000   74.000000
# 75%     35.000000   32.000000   46.000000   60.000000   22.000000  133.000000
# max     83.000000  114.000000  186.000000  219.000000   51.000000  328.000000

# %%
dataset.describe().T.style.background_gradient(cmap = "Purples")
# Out:
# <style type="text/css">
# #T_e537a_row0_col0, #T_e537a_row1_col0, #T_e537a_row2_col0, #T_e537a_row2_col3, #T_e537a_row3_col0, #T_e537a_row3_col3, #T_e537a_row4_col0, #T_e537a_row4_col1, #T_e537a_row4_col2, #T_e537a_row4_col3, #T_e537a_row4_col4, #T_e537a_row4_col5, #T_e537a_row4_col6, #T_e537a_row4_col7, #T_e537a_row5_col0, #T_e537a_row5_col3, #T_e537a_row6_col0, #T_e537a_row6_col3, #T_e537a_row7_col0, #T_e537a_row7_col3, #T_e537a_row8_col0, #T_e537a_row8_col3, #T_e537a_row9_col0, #T_e537a_row9_col1, #T_e537a_row9_col2, #T_e537a_row9_col3, #T_e537a_row9_col4, #T_e537a_row9_col5, #T_e537a_row9_col6, #T_e537a_row9_col7, #T_e537a_row10_col0, #T_e537a_row10_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_e537a_row0_col1 {
#   background-color: #613f9a;
#   color: #f1f1f1;
# }
# #T_e537a_row0_col2 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_e537a_row0_col3, #T_e537a_row0_col7, #T_e537a_row1_col1, #T_e537a_row1_col2, #T_e537a_row1_col4, #T_e537a_row1_col5, #T_e537a_row1_col6 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_e537a_row0_col4 {
#   background-color: #4a1587;
#   color: #f1f1f1;
# }
# #T_e537a_row0_col5, #T_e537a_row0_col6 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_e537a_row1_col3 {
#   background-color: #c8c8e2;
#   color: #000000;
# }
# #T_e537a_row1_col7 {
#   background-color: #4d1b89;
#   color: #f1f1f1;
# }
# #T_e537a_row2_col1 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_e537a_row2_col2 {
#   background-color: #cccce4;
#   color: #000000;
# }
# #T_e537a_row2_col4 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_e537a_row2_col5 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_e537a_row2_col6 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_e537a_row2_col7 {
#   background-color: #a4a1cc;
#   color: #f1f1f1;
# }
# #T_e537a_row3_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_e537a_row3_col2, #T_e537a_row8_col2 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_e537a_row3_col4, #T_e537a_row6_col7, #T_e537a_row8_col6 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_e537a_row3_col5 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_e537a_row3_col6, #T_e537a_row10_col4 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_e537a_row3_col7, #T_e537a_row7_col2, #T_e537a_row10_col1, #T_e537a_row10_col6 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_e537a_row5_col1, #T_e537a_row5_col4, #T_e537a_row5_col5, #T_e537a_row5_col6, #T_e537a_row6_col1, #T_e537a_row6_col4, #T_e537a_row6_col5, #T_e537a_row6_col6, #T_e537a_row7_col4, #T_e537a_row7_col5 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_e537a_row5_col2, #T_e537a_row5_col7, #T_e537a_row6_col2, #T_e537a_row7_col6, #T_e537a_row8_col4, #T_e537a_row8_col5 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_e537a_row7_col1, #T_e537a_row8_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_e537a_row7_col7 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_e537a_row8_col7 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_e537a_row10_col2 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_e537a_row10_col5 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_e537a_row10_col7 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# </style>
# <table id="T_e537a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e537a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e537a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_e537a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_e537a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_e537a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e537a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e537a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e537a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e537a_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_e537a_row0_col0" class="data row0 col0" >407.000000</td>
#       <td id="T_e537a_row0_col1" class="data row0 col1" >1095.027027</td>
#       <td id="T_e537a_row0_col2" class="data row0 col2" >342.841268</td>
#       <td id="T_e537a_row0_col3" class="data row0 col3" >550.000000</td>
#       <td id="T_e537a_row0_col4" class="data row0 col4" >839.000000</td>
#       <td id="T_e537a_row0_col5" class="data row0 col5" >1021.000000</td>
#       <td id="T_e537a_row0_col6" class="data row0 col6" >1270.500000</td>
#       <td id="T_e537a_row0_col7" class="data row0 col7" >2517.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e537a_level0_row1" class="row_heading level0 row1" >altitude</th>
#       <td id="T_e537a_row1_col0" class="data row1 col0" >407.000000</td>
#       <td id="T_e537a_row1_col1" class="data row1 col1" >1358.781327</td>
#       <td id="T_e537a_row1_col2" class="data row1 col2" >508.322847</td>
#       <td id="T_e537a_row1_col3" class="data row1 col3" >180.000000</td>
#       <td id="T_e537a_row1_col4" class="data row1 col4" >900.000000</td>
#       <td id="T_e537a_row1_col5" class="data row1 col5" >1441.000000</td>
#       <td id="T_e537a_row1_col6" class="data row1 col6" >1800.000000</td>
#       <td id="T_e537a_row1_col7" class="data row1 col7" >2300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e537a_level0_row2" class="row_heading level0 row2" >totalPiste</th>
#       <td id="T_e537a_row2_col0" class="data row2 col0" >407.000000</td>
#       <td id="T_e537a_row2_col1" class="data row2 col1" >220.270270</td>
#       <td id="T_e537a_row2_col2" class="data row2 col2" >164.592139</td>
#       <td id="T_e537a_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_e537a_row2_col4" class="data row2 col4" >110.000000</td>
#       <td id="T_e537a_row2_col5" class="data row2 col5" >185.000000</td>
#       <td id="T_e537a_row2_col6" class="data row2 col6" >282.000000</td>
#       <td id="T_e537a_row2_col7" class="data row2 col7" >1220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e537a_level0_row3" class="row_heading level0 row3" >totalLifts</th>
#       <td id="T_e537a_row3_col0" class="data row3 col0" >407.000000</td>
#       <td id="T_e537a_row3_col1" class="data row3 col1" >60.395577</td>
#       <td id="T_e537a_row3_col2" class="data row3 col2" >39.025295</td>
#       <td id="T_e537a_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_e537a_row3_col4" class="data row3 col4" >30.000000</td>
#       <td id="T_e537a_row3_col5" class="data row3 col5" >55.000000</td>
#       <td id="T_e537a_row3_col6" class="data row3 col6" >82.000000</td>
#       <td id="T_e537a_row3_col7" class="data row3 col7" >206.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e537a_level0_row4" class="row_heading level0 row4" >gondolas</th>
#       <td id="T_e537a_row4_col0" class="data row4 col0" >407.000000</td>
#       <td id="T_e537a_row4_col1" class="data row4 col1" >9.108108</td>
#       <td id="T_e537a_row4_col2" class="data row4 col2" >8.398517</td>
#       <td id="T_e537a_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_e537a_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_e537a_row4_col5" class="data row4 col5" >8.000000</td>
#       <td id="T_e537a_row4_col6" class="data row4 col6" >11.000000</td>
#       <td id="T_e537a_row4_col7" class="data row4 col7" >43.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e537a_level0_row5" class="row_heading level0 row5" >chairlifts</th>
#       <td id="T_e537a_row5_col0" class="data row5 col0" >407.000000</td>
#       <td id="T_e537a_row5_col1" class="data row5 col1" >24.766585</td>
#       <td id="T_e537a_row5_col2" class="data row5 col2" >16.968010</td>
#       <td id="T_e537a_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_e537a_row5_col4" class="data row5 col4" >12.000000</td>
#       <td id="T_e537a_row5_col5" class="data row5 col5" >22.000000</td>
#       <td id="T_e537a_row5_col6" class="data row5 col6" >35.000000</td>
#       <td id="T_e537a_row5_col7" cla

# %%
dataset['distance_lift']   = pd.to_numeric(dataset['distance_lift'], errors='coerce').astype('Int64')
dataset['sleeps']          = pd.to_numeric(dataset['sleeps'], errors='coerce').astype('Int64')
dataset['decSnowLow2020']  = pd.to_numeric(dataset['decSnowLow2020'], errors='coerce').astype('Int64')
dataset['decSnowHigh2020'] = pd.to_numeric(dataset['decSnowHigh2020'], errors='coerce').astype('Int64')
dataset['janSnowLow2020']  = pd.to_numeric(dataset['janSnowLow2020'], errors='coerce').astype('Int64')
dataset['janSnowHigh2020'] = pd.to_numeric(dataset['janSnowHigh2020'], errors='coerce').astype('Int64')
dataset['febSnowLow2020'] = pd.to_numeric(dataset['febSnowLow2020'], errors='coerce').astype('Int64')
dataset['febSnowHigh2020'] = pd.to_numeric(dataset['febSnowHigh2020'], errors='coerce').astype('Int64')

# %%
# Mostra as informações do dataset
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          407 non-null    object
#  1   resort           407 non-null    object
#  2   hotel            407 non-null    object
#  3   price            407 non-null    int64
#  4   distance_lift    215 non-null    Int64
#  5   altitude         407 non-null    int64
#  6   totalPiste       407 non-null    int64
#  7   totalLifts       407 non-null    int64
#  8   gondolas         407 non-null    int64
#  9   chairlifts       407 non-null    int64
#  10  draglifts        407 non-null    int64
#  11  blues            407 non-null    float64
#  12  reds             407 non-null    float64
#  13  blacks           407 non-null    float64
#  14  totalRuns        407 non-null    float64
#  15  link             407 non-null    object
#  16  sleeps           311 non-null    Int64
#  17  decSnowLow2020   351 non-null    Int64
#  18  decSnowHigh2020  351 non-null    Int64
#  19  janSnowLow2020   351 non-null    Int64
#  20  janSnowHigh2020  351 non-null    Int64
#  21  febSnowLow2020   351 non-null    Int64
#  22  febSnowHigh2020  351 non-null    Int64
# dtypes: Int64(8), float64(4), int64(7), object(4)
# memory usage: 76.4+ KB
# None

# %%
dataset.head()
# Out:
#     country        resort                   hotel  price  distance_lift  \
# 0     italy  bardonecchia         residence-tabor    550           <NA>
# 1     italy  bardonecchia  residence-villa-frejus    561           <NA>
# 2  bulgaria        bansko              hotel-mura    566           1100
# 3  bulgaria      borovets           hotel-samokov    574             75
# 4  bulgaria        bansko     hotel-lion---bansko    596            800
#
#    altitude  totalPiste  totalLifts  gondolas  chairlifts  ...  blacks  \
# 0      1312         140          23         0           9  ...     1.0
# 1      1312         140          23         0           9  ...     1.0
# 2       935          70          24         1           7  ...     1.0
# 3      1390          58          18         1           4  ...     1.0
# 4       935          70          24         1           7  ...     1.0
#
#    totalRuns                                               link  sleeps  \
# 0       42.0  https://www.igluski.com/ski-resorts/italy/bard...    <NA>
# 1       42.0  https://www.igluski.com/ski-resorts/italy/bard...    <NA>
# 2       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...     140
# 3       15.0  https://www.igluski.com/ski-resorts/bulgaria/b...     590
# 4       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...     386
#
#    decSnowLow2020 decSnowHigh2020  janSnowLow2020  janSnowHigh2020  \
# 0              70             170              60              200
# 1              70             170              60              200
# 2               0              70               5               75
# 3               0               0             160              200
# 4               0              70               5               75
#
#    febSnowLow2020  febSnowHigh2020
# 0              47              177
# 1              47              177
# 2               5               77
# 3             194              246
# 4               5               77
#
# [5 rows x 23 columns]

# %%
## Faz um resumo estatístico do dataset (média, desvio padrão, mínimo, máximo e os quartis)
dataset.describe()
# Out:
#              price  distance_lift     altitude   totalPiste  totalLifts  \
# count   407.000000          215.0   407.000000   407.000000  407.000000
# mean   1095.027027     362.674419  1358.781327   220.270270   60.395577
# std     342.841268     387.668789   508.322847   164.592139   39.025295
# min     550.000000            5.0   180.000000     0.000000    0.000000
# 25%     839.000000          100.0   900.000000   110.000000   30.000000
# 50%    1021.000000          200.0  1441.000000   185.000000   55.000000
# 75%    1270.500000          500.0  1800.000000   282.000000   82.000000
# max    2517.000000         3000.0  2300.000000  1220.000000  206.000000
#
#          gondolas  chairlifts   draglifts       blues        reds      blacks  \
# count  407.000000  407.000000  407.000000  407.000000  407.000000  407.000000
# mean     9.108108   24.766585   25.189189   41.115479   45.685504   14.007371
# std      8.398517   16.968010   19.300095   40.742178   38.777112   12.131969
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000   12.000000   12.000000   16.000000   18.000000    4.000000
# 50%      8.000000   22.000000   21.000000   30.000000   37.000000    9.000000
# 75%     11.000000   35.000000   32.000000   46.000000   60.000000   22.000000
# max     43.000000   83.000000  114.000000  186.000000  219.000000   51.000000
#
#         totalRuns      sleeps  decSnowLow2020  decSnowHigh2020  \
# count  407.000000       311.0           351.0            351.0
# mean   100.808354  140.045016       37.091168        107.48433
# std     81.835216  123.025927       41.259911        83.650013
# min      0.000000         2.0             0.0              0.0
# 25%     40.000000        70.0             0.0             50.0
# 50%     74.000000       102.0            27.0            100.0
# 75%    133.000000       164.5            70.5            165.0
# max    328.000000      1200.0           150.0            400.0
#
#        janSnowLow2020  janSnowHigh2020  febSnowLow2020  febSnowHigh2020
# count           351.0            351.0           351.0            351.0
# mean        67.461538       167.441595       69.210826        174.65812
# std         50.751699        76.211895       50.188058        73.724293
# min               0.0             70.0             0.0             74.0
# 25%              40.0            120.0            45.0            130.0
# 50%              50.0            147.0            50.0            150.0
# 75%              72.5            200.0            90.0            223.0
# max             215.0            400.0           207.0            400.0

# %%
desc = dataset["country"].describe()
desc
# Out:
# count         407
# unique          6
# top       austria
# freq          169
# Name: country, dtype: object

# %% [markdown]
# Os valores na coluna **country** incluem *seis países exclusivos*, que são: Áustria, Itália, França, Andorra, Finlândia e Bulgária.  A **Áustria** é o país mais frequentado com **169 hotéis de esqui**.

# %%
desc = dataset["resort"].describe()
desc
# Out:
# count             407
# unique             92
# top       zell-am-see
# freq               15
# Name: resort, dtype: object

# %% [markdown]
# Os valores na coluna **resort** incluem *92 resorts exclusivos*.  **Zell-am-See** é o  resort mais frequentado com **15 hotéis de esqui**.

# %%
desc = dataset["hotel"].describe()
desc
# Out:
# count              407
# unique             396
# top       hotel-alpina
# freq                 3
# Name: hotel, dtype: object

# %% [markdown]
# Os valores na coluna **hotel** incluem *396 hotéis (de esqui) exclusivo*s. O **Hotel Alpina** é o mais frequente, com **3 ocorrências**, siginificando que essa rede está em outros 3 Resorts de Esqui.

# %% [markdown]
# ###3.2.Visualizações Unimodais
#
# Vamos criar agora um **histograma** para cada atributo (varável quantitativa) do dataset.

# %%
# Histograma
dataset.hist(figsize = (13,13))
plt.show()

# %% [markdown]
# O **Gráfico de Densidade**, ou **Density Plot**, é bem parecido com o histograma, mas com uma visualização um pouco diferente. Com ele, pode ser mais fácil identificar a distribuição dos atributos do dataset.
#
# Veremos que muitos dos atributos têm uma distribuição distorcida. Uma transformação como a **Box-Cox**, que pode aproximar a distribuição de uma Normal, pode ser útil neste caso.

# %%
# Density Plot
dataset.plot(kind = 'density', subplots = True, layout = (12,2), sharex = False, figsize = (15,24))
plt.show()

# %% [markdown]
# Vamos agora trabalhar com **boxplot**s. No boxblot, a linha no centro (vermelha) representa o valor da mediana (segundo quartil ou p50). A linha abaixo é o 1o quartil (p25) e a linha acima o terceiro quartil (p75). O boxplot ajuda a ter uma ideia da dispersão dos dataset e os possíveis outliers.
#
# OBS: Se um ponto do dataset é muito distante da média (acima de 3 desvios padrão da média), pode ser considerado outlier.
#
# Nos gráficos bloxplot, veremos que a dispersão dos atributos do dataset é bem diferente.
# OBS: Se um ponto do dataset é muito distante da média (acima de 3 desvios padrão da média), pode ser considerado outlier.
#
# Nos gráficos bloxplot, veremos que a dispersão dos atributos do dataset é bem diferente.

# %%
# Boxplot
dataset.plot(kind = 'box', subplots = True, layout = (12 ,3), sharex = False, sharey = False, figsize = (15, 26))
plt.show()

# %% [markdown]
# Inspecionar recursos categóricos de baixa cardinalidade:

# %%
# Color Palette
custom_colors = ['#9357b4', '#c193dd', '#e1c2f2', '#ffb500', '#36c9dd']
sns.palplot(sns.color_palette(custom_colors))

# Set Style
sns.set_style("whitegrid")
sns.despine(left=True, bottom=True)

# Set tick size
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)

# %%
def barplot_features(df, feature, title, palette = custom_colors[2:]):
    '''Takes the numerical columns and plots the barplot.'''

    # We need to extract both the name of the category and the no. of appearences
    index = df[feature].value_counts().reset_index()["index"].values
    values = df[feature].value_counts().reset_index()[feature].values 

    plt.figure(figsize = (18, 3))
    sns.barplot(x = index, y = values, palette = palette)
    plt.title(title, fontsize=15)
    plt.show();

    del index, values
    gc.collect()

# %%
# Inspecionar cardionalidade mínima da coluna country (país)
categorical_for_bar = ['country']
for feature in categorical_for_bar:
      barplot_features(dataset, feature=feature, title = feature + " barplot", palette = custom_colors)

# %% [markdown]
# A **Áustria** é o país *mais frequentado* com **169 hotéis de esqui**, e a **Bulgária** é o *menos frequentado* com apenas **11 hotéis**.

# %% [markdown]
# ###3.3.Visualizações Multimodais

# %% [markdown]
# Ao visualizar as correlações entre os atributos através da matriz de correlação, perceberemos que parece haver alguma estrutura na ordem dos atributos. O azul ao redor da diagonal sugere que os atributos que estão próximos um do outro são geralmente mais correlacionados entre si. Os vermelhos também sugerem alguma correlação negativa moderada, a medida que os atributos
#
# Vamos agora verificar a covariância entre as variáveis numéricas do dataset. A covariância representa como duas variáveis numéricas estão relacionadas. Existem várias formas de calcular a correlação entre duas variáveis, como por exemplo, o coeficiente de correlação de Pearson, que pode ser:
#
# Próximo de -1 : há uma correlação negativa entre as variáveis,
# Próximo de +1: há uma correlação positiva entre as variáveis.
# 0: não há correlação entre as variáveis.
# OBS: Esta informação é relevante porque alguns algoritmos como regressão linear e regressão logística podem apresentar problemas de performance se houver atributos altamente correlacionados. Vale a pena consultar a documentação do algoritmo para verificar se algum tipo de tratamento de dataset é necessário.
#
# Falamos anteriormente da importância da correlação entre os atributos, e agora iremos visualizar esta informação em formato gráfico. A matriz de correlação exibe graficamente a correlação entre os atributos numéricos do dataset.estão mais distantes um do outro na ordenação.
#
# O código a seguir exibe a matriz de correlação.

# %% [markdown]
# Por sua vez, o gráfico de dispersão (scatter plot) mostra o relacionamento entre duas variáveis. Vamos exibir um para cada par de atributos dos dataset, usando o Seaborn.

# %%
# Matriz de Correlação com Matplotlib Seaborn
sns.heatmap(dataset.corr(), annot=True, cmap='RdBu');

# %%
dataset.corr().style.background_gradient(cmap = "Purples")
# Out:
# <style type="text/css">
# #T_f187a_row0_col0, #T_f187a_row1_col1, #T_f187a_row2_col2, #T_f187a_row3_col3, #T_f187a_row4_col4, #T_f187a_row5_col5, #T_f187a_row6_col6, #T_f187a_row7_col7, #T_f187a_row8_col8, #T_f187a_row9_col9, #T_f187a_row10_col10, #T_f187a_row11_col11, #T_f187a_row12_col12, #T_f187a_row13_col13, #T_f187a_row14_col14, #T_f187a_row15_col15, #T_f187a_row16_col16, #T_f187a_row17_col17, #T_f187a_row18_col18 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_f187a_row0_col1, #T_f187a_row1_col0, #T_f187a_row1_col2, #T_f187a_row1_col3, #T_f187a_row1_col4, #T_f187a_row1_col5, #T_f187a_row1_col6, #T_f187a_row1_col7, #T_f187a_row1_col8, #T_f187a_row1_col10, #T_f187a_row1_col11, #T_f187a_row1_col13, #T_f187a_row1_col14, #T_f187a_row1_col15, #T_f187a_row1_col16, #T_f187a_row1_col17, #T_f187a_row1_col18, #T_f187a_row9_col12, #T_f187a_row9_col14, #T_f187a_row11_col14, #T_f187a_row12_col9, #T_f187a_row13_col12, #T_f187a_row14_col9 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_f187a_row0_col2 {
#   background-color: #d3d3e8;
#   color: #000000;
# }
# #T_f187a_row0_col3, #T_f187a_row0_col9, #T_f187a_row3_col17, #T_f187a_row11_col18 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_f187a_row0_col4 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_f187a_row0_col5, #T_f187a_row5_col17, #T_f187a_row16_col10 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_f187a_row0_col6, #T_f187a_row7_col18 {
#   background-color: #c8c8e2;
#   color: #000000;
# }
# #T_f187a_row0_col7, #T_f187a_row2_col9 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_f187a_row0_col8, #T_f187a_row15_col18 {
#   background-color: #b9b9da;
#   color: #000000;
# }
# #T_f187a_row0_col10 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_f187a_row0_col11, #T_f187a_row3_col16, #T_f187a_row17_col9, #T_f187a_row18_col4 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_f187a_row0_col12 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_f187a_row0_col13, #T_f187a_row13_col8 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_f187a_row0_col14, #T_f187a_row4_col14, #T_f187a_row14_col3 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_f187a_row0_col15, #T_f187a_row3_col0, #T_f187a_row9_col0, #T_f187a_row9_col13 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_f187a_row0_col16, #T_f187a_row14_col0 {
#   background-color: #e5e4f0;
#   color: #000000;
# }
# #T_f187a_row0_col17, #T_f187a_row12_col15, #T_f187a_row18_col0, #T_f187a_row18_col9 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_f187a_row0_col18 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_f187a_row1_col9, #T_f187a_row6_col12, #T_f187a_row8_col14 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_f187a_row1_col12 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_f187a_row2_col0, #T_f187a_row17_col3 {
#   background-color: #cecee5;
#   color: #000000;
# }
# #T_f187a_row2_col1, #T_f187a_row3_col12, #T_f187a_row5_col12, #T_f187a_row10_col12, #T_f187a_row12_col3, #T_f187a_row12_col14 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_f187a_row2_col3, #T_f187a_row18_col8 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_f187a_row2_col4, #T_f187a_row15_col9 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_f187a_row2_col5, #T_f187a_row16_col0 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_f187a_row2_col6, #T_f187a_row6_col16 {
#   background-color: #aeacd2;
#   color: #000000;
# }
# #T_f187a_row2_col7, #T_f187a_row17_col12 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_f187a_row2_col8 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_f187a_row2_col10, #T_f187a_row13_col6, #T_f187a_row17_col18 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_f187a_row2_col11, #T_f187a_row3_col18, #T_f187a_row8_col13, #T_f187a_row18_col3 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_f187a_row2_col12 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_f187a_row2_col13, #T_f187a_row3_col8, #T_f187a_row16_col2 {
#   background-color: #7d78b7;
#   color: #f1f1f1;
# }
# #T_f187a_row2_col14, #T_f187a_row5_col15, #T_f187a_row15_col5, #T_f187a_row17_col10 {
#   background-color: #9490c3;
#   color: #f1f1f1;
# }
# #T_f187a_row2_col15, #T_f187a_row13_col17 {
#   background-color: #9a96c6;
#   color: #f1f1f1;
# }
# #T_f187a_row2_col16, #T_f187a_row8_col7, #T_f187a_row13_col2 {
#   background-color: #7d77b7;
#   color: #f1f1f1;
# }
# #T_f187a_row2_col17 {
#   background-color: #aaa8d0;
#   color: #000000;
# }
# #T_f187a_row2_col18, #T_f187a_row13_col16 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col1, #T_f187a_row14_col1, #T_f187a_row18_col1 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_f187a_row3_col2, #T_f187a_row8_col16 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_f187a_row3_col4 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col5, #T_f187a_row14_col13 {
#   background-color: #827fbb;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col6 {
#   background-color: #6d57a6;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col7, #T_f187a_row8_col3 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col9, #T_f187a_row6_col11, #T_f187a_row9_col3, #T_f187a_row11_col6, #T_f187a_row14_col16 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col10 {
#   background-color: #7970b3;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col11 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_f187a_row3_col13, #T_f187a_row4_col2, #T_f187a_row9_col15, #T_f187a_row16_col7, #T_f187a_row18_col6 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_f187a_row3_col14, #T_f187a_row7_col1, #T_f187a_row9_col1, #T_f187a_row14_col10, #T_f187a_row14_col15 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_f187a_row3_col15, #T_f187a_row7_col2, #T_f187a_row11_col2, #T_f187a_row13_col11, #T_f187a_row18_col7 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_f187a_row4_col0, #T_f187a_row6_col18 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_f187a_row4_col1, #T_f187a_row5_col1, #T_f187a_row12_col5, #T_f187a_row12_col13, #T_f187a_row14_col7, #T_f187a_row15_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_f187a_row4_col3, #T_f187a_row14_col18, #T_f187a_row18_col14 {
#   background-color: #6e58a7;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col5, #T_f187a_row5_col4, #T_f187a_row5_col11, #T_f187a_row11_col5 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col6, #T_f187a_row6_col4, #T_f187a_row15_col17 {
#   background-color: #4a1486;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col7, #T_f187a_row7_col4 {
#   background-color: #4a1587;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col8, #T_f187a_row10_col9 {
#   background-color: #62429c;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col9 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col10 {
#   background-color: #7262ac;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col11, #T_f187a_row11_col4 {
#   background-color: #5d3897;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col12, #T_f187a_row12_col11 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_f187a_row4_col13, #T_f187a_row4_col16 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_f187a_row4_col15, #T_f187a_row5_col7, #T_f187a_row14_col2, #T_f187a_row15_col4 {
#   background-color: #8e8ac0;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col17, #T_f187a_row15_col6 {
#   background-color: #9995c6;
#   color: #f1f1f1;
# }
# #T_f187a_row4_col18, #T_f187a_row11_col13 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_f187a_row5_col0, #T_f187a_row15_col7, #T_f187a_row15_col13 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# #T_f187a_row5_col2, #T_f187a_row8_col18, #T_f187a_row9_col18, #T_f187a_row12_col0 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_f187a_row5_col3 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_f187a_row5_col6 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_f187a_row5_col8, #T_f187a_row6_col8, #T_f187a_row8_col6, #T_f187a_row11_col3, #T_f187a_row16_col14 {
#   background-color: #674ba0;
#   color: #f1f1f1;
# }
# #T_f187a_row5_col9, #T_f187a_row10_col3 {
#   background-color: #7c75b6;
#   color: #f1f1f1;
# }
# #T_f187a_row5_col10 {
#   background-color: #918ec2;
#   color: #f1f

# %% [markdown]
# ##4.Pré-processamento de Dados
#
# Nesta etapa, poderíamos realizar diversas operações de preparação de dados, como por exemplo, tratamento de valores missings (faltantes), limpeza de dados, transformações como one-hot-encoding, seleção de características (feature selection), entre outras não mostradas neste notebook. Lembre-se de não criar uma versão padronizada/normalizada dos dados neste momento (apesar de serem operações de pré-processamento) para evitar o Data Leakage.

# %% [markdown]
# ###4.1.Tratamento de Missings e Limpeza
#
# Sabemos que o datset ski_hotels não tem missings aparentes, mas valores "0" que parecem ser missings. Vamos então fazer este tratamento e criar uma nova visão do nosso dataset.

# %%
# verificando nulls no dataset
dataset.isnull().sum()
# Out:
# country              0
# resort               0
# hotel                0
# price                0
# distance_lift      192
# altitude             0
# totalPiste           0
# totalLifts           0
# gondolas             0
# chairlifts           0
# draglifts            0
# blues                0
# reds                 0
# blacks               0
# totalRuns            0
# link                 0
# sleeps              96
# decSnowLow2020      56
# decSnowHigh2020     56
# janSnowLow2020      56
# janSnowHigh2020     56
# febSnowLow2020      56
# febSnowHigh2020     56
# dtype: int64

# %% [markdown]
# Verificamos através do comando acima que exitem várias colunas com valores ausentes (missings) no dataset **ski_hotels**. Exemplo considerável é a coluna "**distance_lift**" tem 192 missings, (47,17%).

# %%
# Exibindo as dimensões do dataset
print(dataset.shape)
# Out:
# (407, 23)

# %%
# Salvando um NOVO dataset para tratamento de missings 

# Recuperando os nomes das colunas
col = list(dataset.columns)

# O novo dataset irá conter todas as colunas do dataset original
atributos = dataset[col[:]]

# Eliminando linhas que tenham ALGUM valor missing
atributos.dropna(how='any', inplace=True)

# %%
# Exibindo as dimensões do dataset
print(atributos.shape)
# Out:
# (147, 23)

# %%
# substituindo os zeros por NaN
atributos.replace(0, np.nan, inplace=True)

# exibindo visualização matricial da nulidade do dataset
ms.matrix(atributos)
# Out:
# <Axes: >

# %%
# Verificando novamente nulls no dataset
atributos.isnull().sum()
# Out:
# country             0
# resort              0
# hotel               0
# price               0
# distance_lift       0
# altitude            0
# totalPiste          1
# totalLifts          3
# gondolas            8
# chairlifts          3
# draglifts           3
# blues               3
# reds                3
# blacks              3
# totalRuns           3
# link                0
# sleeps              0
# decSnowLow2020     49
# decSnowHigh2020    13
# janSnowLow2020      4
# janSnowHigh2020     0
# febSnowLow2020      4
# febSnowHigh2020     0
# dtype: int64

# %%
# Removendo as colunas 'decSnowLow20201'e 'decSnowHigh2020'
atributos.drop(['decSnowLow2020', 'decSnowHigh2020'], axis=1, inplace= True)

# %%
# Exibindo visualização matricial da nulidade do dataset
ms.matrix(atributos)
# Out:
# <Axes: >

# %%
# substituindo os NaN de 'plas', 'pres'e 'mass' pela mediana da coluna
atributos['totalPiste'].fillna(atributos['totalPiste'].median(), inplace=True)
atributos['totalLifts'].fillna(atributos['totalLifts'].median(), inplace=True)
atributos['gondolas'].fillna(atributos['gondolas'].median(), inplace=True)
atributos['chairlifts'].fillna(atributos['chairlifts'].median(), inplace=True)
atributos['totalLifts'].fillna(atributos['totalLifts'].median(), inplace=True)
atributos['gondolas'].fillna(atributos['gondolas'].median(), inplace=True)
atributos['draglifts'].fillna(atributos['draglifts'].median(), inplace=True)
atributos['blues'].fillna(atributos['blues'].median(), inplace=True)
atributos['reds'].fillna(atributos['reds'].median(), inplace=True)
atributos['blacks'].fillna(atributos['blacks'].median(), inplace=True)
atributos['totalRuns'].fillna(atributos['totalRuns'].median(), inplace=True)
atributos['janSnowLow2020'].fillna(atributos['janSnowLow2020'].median(), inplace=True)
atributos['febSnowLow2020'].fillna(atributos['febSnowLow2020'].median(), inplace=True)

# %%
# exibindo visualização matricial da nulidade do dataset
ms.matrix(atributos)
# Out:
# <Axes: >

# %%
# Guardando o novo dataset para testes futuros
datasetSemMissings = atributos

# exibindo as primeiras linhas
datasetSemMissings.head()
# Out:
#     country     resort                hotel  price  distance_lift  altitude  \
# 2  bulgaria     bansko           hotel-mura    566           1100       935
# 3  bulgaria   borovets        hotel-samokov    574             75      1390
# 4  bulgaria     bansko  hotel-lion---bansko    596            800       935
# 5   andorra    arinsal   hotel-xalet-besoli    597            500      1550
# 6   austria  mayrhofen       hotel-obermair    601            600       630
#
#    totalPiste  totalLifts  gondolas  chairlifts  ...  blues  reds  blacks  \
# 2        70.0        24.0       1.0         7.0  ...    5.0   8.0     1.0
# 3        58.0        18.0       1.0         4.0  ...    1.0  13.0     1.0
# 4        70.0        24.0       1.0         7.0  ...    5.0   8.0     1.0
# 5        63.0        30.0       2.0        11.0  ...   22.0  16.0     4.0
# 6       600.0        52.0       8.0        27.0  ...   43.0  75.0    15.0
#
#    totalRuns                                               link sleeps  \
# 2       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...    140
# 3       15.0  https://www.igluski.com/ski-resorts/bulgaria/b...    590
# 4       14.0  https://www.igluski.com/ski-resorts/bulgaria/b...    386
# 5       42.0  https://www.igluski.com/ski-resorts/andorra/ar...     66
# 6      133.0  https://www.igluski.com/ski-resorts/austria/ma...     60
#
#    janSnowLow2020  janSnowHigh2020  febSnowLow2020  febSnowHigh2020
# 2               5               75               5               77
# 3             160              200             194              246
# 4               5               75               5               77
# 5             130              180             120              170
# 6               5               80               2               99
#
# [5 rows x 21 columns]

# %%
# Verificando novamente nulls no dataset
datasetSemMissings.isnull().sum()
# Out:
# country            0
# resort             0
# hotel              0
# price              0
# distance_lift      0
# altitude           0
# totalPiste         0
# totalLifts         0
# gondolas           0
# chairlifts         0
# draglifts          0
# blues              0
# reds               0
# blacks             0
# totalRuns          0
# link               0
# sleeps             0
# janSnowLow2020     0
# janSnowHigh2020    0
# febSnowLow2020     0
# febSnowHigh2020    0
# dtype: int64

# %% [markdown]
# ###4.2.Transformações Numéricas

# %% [markdown]
# ####4.2.1.Normalização

# %%
# Separando os valores dp dataset em componentes de input (x) e output (y)
x = dataset.values[:,0:8]
y = dataset.values[:,8]

# %%
# Exibindo os dados transformados

# %% [markdown]
# ####4.2.2.Padronização

# %% [markdown]
# ###4.3.Separação em conjunto de treino e conjunto de teste

# %% [markdown]
# Como boa prática de usar um conjunto de teste/conjunto de validação, uma amostra dos dados que não será usada para a construção do modelo, mas somente no fim do projeto para confirmar a precisão do modelo final. Para verificação de  quão boa foi a construção do modelo, e para nos dar uma idéia de como o modelo irá performar nas estimativas em dados não vistos. Usaremos 80% do conjunto de dados para modelagem e guardaremos 20% para teste, usando a estratégia train-test-split. Primeiramente, iremos sinalizar quais são as colunas de atributos (X - 0 a 7) e qual é a coluna das classes (Y - 8). Em seguida, especificaremos o tamanho do conjunto de teste desejado e uma semente (para garantir a reprodutibilidade dos resultados). Finalmente, faremos a separação dos conjuntos de treino e teste através do comando train_test_split, que retornará 4 estruturas de dados: os atributos e classes para o conjunto de teste e os atributos e classes para o conjunto de treino

# %%
test_size = 0.20
seed = 7

# Separação em conjuntos de treino e teste (dataset original)
array = dataset.values
X = array[:,0:8]
y = array[:,8]
#X_train, X_test, y_train, y_test = train_test_split(X, y,
#    test_size=test_size, shuffle=True, random_state=seed) # sem estratificação
X_train, X_test, y_train, y_test = train_test_split(X, y,
    test_size=test_size, shuffle=True, random_state=seed, stratify=y) # com estratificação

# %%
# Separação em conjuntos de treino e teste (dataset sem missings - 2 colunas a menos!)
array = datasetSemMissings.values
X_sm = array[:,0:6]
y_sm = array[:,6]
#X_train_sm, X_test_sm, y_train_sm, y_test_sm = train_test_split(X_sm, y_sm,
#   test_size=test_size, shuffle=True, random_state=seed, stratify=y_sm) # com estratificação
X_train_sm, X_test_sm, y_train_sm, y_test_sm = train_test_split(X_sm, y_sm,
   test_size=test_size, shuffle=True, random_state=seed) # sem estratificação
